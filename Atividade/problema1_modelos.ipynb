# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score
from google.colab import drive

# Modelos de classificação
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# 1. Montar o Google Drive
drive.mount('/content/drive')

# 2. Carregar os dados
caminho_arquivo = '/content/drive/MyDrive/TI-Saude/Atividade Zamberlan/dados_predicao_modelos.csv'

try:
    df = pd.read_csv(caminho_arquivo)
    print("Arquivo carregado com sucesso!\n")
except FileNotFoundError:
    print(f"Erro: O arquivo não foi encontrado no caminho: {caminho_arquivo}")
    print("Verifique se o nome do arquivo ou a estrutura de pastas no seu Google Drive correspondem.")

# 3. Features e variável alvo
features = ['Idade', 'Renda_Anual_K', 'Score_Credito', 'Pontuacao_Engajamento']
target = 'Compro_Produto'

X = df[features]
y = df[target]

# 4. Divisão treino/teste com estratificação
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# 5. Padronizar as variáveis
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# 6. Definir modelos
modelos = {
    'Logistic Regression': LogisticRegression(max_iter=1000),
    'Decision Tree': DecisionTreeClassifier(random_state=42),
    'Random Forest': RandomForestClassifier(random_state=42),
    'KNN': KNeighborsClassifier(),
    'Naive Bayes': GaussianNB(),
    'SVM': SVC(),
    'Gradient Boosting': GradientBoostingClassifier(random_state=42)
}

# 7. Avaliar cada modelo e imprimir no terminal
resultados = []

print("=" * 60)
print("DETALHAMENTO DOS MODELOS")
print("=" * 60)

for nome, modelo in modelos.items():
    modelo.fit(X_train, y_train)

    y_pred_train = modelo.predict(X_train)
    y_pred_test = modelo.predict(X_test)

    acc_train = accuracy_score(y_train, y_pred_train)
    f1_train = f1_score(y_train, y_pred_train, average='macro', zero_division=0)

    acc_test = accuracy_score(y_test, y_pred_test)
    f1_test = f1_score(y_test, y_pred_test, average='macro', zero_division=0)

    resultados.append({
        'Modelo': nome,
        'Acc Treino': acc_train,
        'F1 Treino': f1_train,
        'Acc Teste': acc_test,
        'F1 Teste': f1_test
    })

    print(f"\nModelo: {nome}")
    print(f"Acurácia (Treino): {acc_train:.4f} | Acurácia (Teste): {acc_test:.4f}")
    print(f"F1-Score Macro (Treino): {f1_train:.4f} | F1-Score Macro (Teste): {f1_test:.4f}")
    print("\nMatriz de Confusão (Teste):")
    print(confusion_matrix(y_test, y_pred_test))
    print("\nRelatório de Classificação (Teste):")
    print(classification_report(y_test, y_pred_test, zero_division=0))
    print("-" * 60)

# 8. Exibir Ranking Final em Formato de Tabela
df_resultados = pd.DataFrame(resultados)
df_resultados = df_resultados.sort_values(by='F1 Teste', ascending=False)

print("\n" + "=" * 60)
print("RANKING FINAL DOS MODELOS (Ordenado por F1-Score no Teste)")
print("=" * 60)
print(df_resultados.to_string(index=False, formatters={
    'Acc Treino': '{:.4f}'.format,
    'F1 Treino': '{:.4f}'.format,
    'Acc Teste': '{:.4f}'.format,
    'F1 Teste': '{:.4f}'.format
}))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Arquivo carregado com sucesso!
#
# ============================================================
# DETALHAMENTO DOS MODELOS
# ============================================================
#
# Modelo: Logistic Regression
# Acurácia (Treino): 0.7086 | Acurácia (Teste): 0.6533
# F1-Score Macro (Treino): 0.6803 | F1-Score Macro (Teste): 0.6100
#
# Matriz de Confusão (Teste):
# [[37  8]
#  [18 12]]
#
# Relatório de Classificação (Teste):
#               precision    recall  f1-score   support
#
#            0       0.67      0.82      0.74        45
#            1       0.60      0.40      0.48        30
#
#     accuracy                           0.65        75
#    macro avg       0.64      0.61      0.61        75
# weighted avg       0.64      0.65      0.64        75
#
# ------------------------------------------------------------
#
# Modelo: Decision Tree
# Acurácia (Treino): 1.0000 | Acurácia (Teste): 0.6533
# F1-Score Macro (Treino): 1.0000 | F1-Score Macro (Teste): 0.6346
#
# Matriz de Confusão (Teste):
# [[33 12]
#  [14 16]]
#
# Relatório de Classificação (Teste):
#               precision    recall  f1-score   support
#
#            0       0.70      0.73      0.72        45
#            1       0.57      0.53      0.55        30
#
#     accuracy                           0.65        75
#    macro avg       0.64      0.63      0.63        75
# weighted avg       0.65      0.65      0.65        75
#
# ------------------------------------------------------------
#
# Modelo: Random Forest
# Acurácia (Treino): 1.0000 | Acurácia (Teste): 0.6933
# F1-Score Macro (Treino): 1.0000 | F1-Score Macro (Teste): 0.6514
#
# Matriz de Confusão (Teste):
# [[39  6]
#  [17 13]]
#
# Relatório de Classificação (Teste):
#               precision    recall  f1-score   support
#
#            0       0.70      0.87      0.77        45
#            1       0.68      0.43      0.53        30
#
#     accuracy                           0.69        75
#    macro avg       0.69      0.65      0.65        75
# weighted avg       0.69      0.69      0.68        75
#
# ------------------------------------------------------------
#
# Modelo: KNN
# Acurácia (Treino): 0.7771 | Acurácia (Teste): 0.6533
# F1-Score Macro (Treino): 0.7606 | F1-Score Macro (Teste): 0.6238
#
# Matriz de Confusão (Teste):
# [[35 10]
#  [16 14]]
#
# Relatório de Classificação (Teste):
#               precision    recall  f1-score   support
#
#            0       0.69      0.78      0.73        45
#            1       0.58      0.47      0.52        30
#
#     accuracy                           0.65        75
#    macro avg       0.63      0.62      0.62        75
# weighted avg       0.65      0.65      0.64        75
#
# ------------------------------------------------------------
#
# Modelo: Naive Bayes
# Acurácia (Treino): 0.7200 | Acurácia (Teste): 0.6533
# F1-Score Macro (Treino): 0.6951 | F1-Score Macro (Teste): 0.6100
#
# Matriz de Confusão (Teste):
# [[37  8]
#  [18 12]]
#
# Relatório de Classificação (Teste):
#               precision    recall  f1-score   support
#
#            0       0.67      0.82      0.74        45
#            1       0.60      0.40      0.48        30
#
#     accuracy                           0.65        75
#    macro avg       0.64      0.61      0.61        75
# weighted avg       0.64      0.65      0.64        75
#
# ------------------------------------------------------------
#
# Modelo: SVM
# Acurácia (Treino): 0.7771 | Acurácia (Teste): 0.6800
# F1-Score Macro (Treino): 0.7452 | F1-Score Macro (Teste): 0.6237
#
# Matriz de Confusão (Teste):
# [[40  5]
#  [19 11]]
#
# Relatório de Classificação (Teste):
#               precision    recall  f1-score   support
#
#            0       0.68      0.89      0.77        45
#            1       0.69      0.37      0.48        30
#
#     accuracy                           0.68        75
#    macro avg       0.68      0.63      0.62        75
# weighted avg       0.68      0.68      0.65        75
#
# ------------------------------------------------------------
#
# Modelo: Gradient Boosting
# Acurácia (Treino): 0.9943 | Acurácia (Teste): 0.6000
# F1-Score Macro (Treino): 0.9940 | F1-Score Macro (Teste): 0.5297
#
# Matriz de Confusão (Teste):
# [[37  8]
#  [22  8]]
#
# Relatório de Classificação (Teste):
#               precision    recall  f1-score   support
#
#            0       0.63      0.82      0.71        45
#            1       0.50      0.27      0.35        30
#
#     accuracy                           0.60        75
#    macro avg       0.56      0.54      0.53        75
# weighted avg       0.58      0.60      0.57        75
#
# ------------------------------------------------------------
#
# ============================================================
# RANKING FINAL DOS MODELOS (Ordenado por F1-Score no Teste)
# ============================================================
#              Modelo Acc Treino F1 Treino Acc Teste F1 Teste
#       Random Forest     1.0000    1.0000    0.6933   0.6514
#       Decision Tree     1.0000    1.0000    0.6533   0.6346
#                 KNN     0.7771    0.7606    0.6533   0.6238
#                 SVM     0.7771    0.7452    0.6800   0.6237
# Logistic Regression     0.7086    0.6803    0.6533   0.6100
#         Naive Bayes     0.7200    0.6951    0.6533   0.6100
#   Gradient Boosting     0.9943    0.9940    0.6000   0.5297
